# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time
import random
from random import randint

# %%
zipcode_dict = dict() #dictionary of Zip Codes by Neighborhood
zipcode_dict['Chelsea and Clinton'] = ['10001', '10011', '10018', '10019', '10020', '10036']
zipcode_dict['Central Harlem'] = ['10026', '10027', '10030', '10037', '10039']
zipcode_dict['East Harlem'] = ['10029', '10035']
zipcode_dict['East Harlem'] = ['10029', '10035']
zipcode_dict['Gramercy Park and Murray Hill'] = ['10010', '10016', '10017', '10022']
zipcode_dict['Greenwich Village and Soho'] = ['10012', '10013', '10014']
zipcode_dict['Lower Manhattan'] =['10004', '10005', '10006', '10007', '10038', '10280']
zipcode_dict['Lower East Side'] =['10002', '10003', '10009']
zipcode_dict['Upper East Side'] =['10021', '10028', '10044', '10065', '10075', '10128']
zipcode_dict['Upper West Side'] =['10023', '10024', '10025']
zipcode_dict['Upper West Side'] =['10031', '10032', '10033', '10034', '10040']

# %%
zipcode_dict
# Out:
# {'Central Harlem': ['10026', '10027', '10030', '10037', '10039'],
#  'Chelsea and Clinton': ['10001', '10011', '10018', '10019', '10020', '10036'],
#  'East Harlem': ['10029', '10035'],
#  'Gramercy Park and Murray Hill': ['10010', '10016', '10017', '10022'],
#  'Greenwich Village and Soho': ['10012', '10013', '10014'],
#  'Lower East Side': ['10002', '10003', '10009'],
#  'Lower Manhattan': ['10004', '10005', '10006', '10007', '10038', '10280'],
#  'Upper East Side': ['10021', '10028', '10044', '10065', '10075', '10128'],
#  'Upper West Side': ['10023', '10024', '10025']}

# %%
zip_code_dict = dict()
#List of Zip Codes by Neighborhood
zipcode_list = ['10001', '10011', '10018', '10019', '10020', '10036']

# %%
def get_links(zipcode_list): # get link of each home on the Zillow market
    link_list = list()
    req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
    }
    with requests.Session() as s:
        for zipcode in zipcode_list:     
            for i in range(1, 25):
                try:
                    page_url = 'https://www.zillow.com/homes/'+zipcode+'_rb/'+str(i)+'_p/'
                    r = s.get(page_url, headers=req_headers)
                    soup = BeautifulSoup(r.content, 'lxml')
                    tags = soup.find_all('div', {'class': 'zsg-photo-card-content zsg-aspect-ratio-content'})
                    for tag in tags:
                        link_list.append(tag.find('a').get('href'))
                except:
                    # no next page
                    break
        time.sleep(5)
    return link_list

# %%
links = get_links(zipcode_dict[''])

# %%
links
# Out:
# ['/b/507-W-28th-St-New-York-NY/40.75109,-74.002129_ll/',
#  '/b/9-W-32nd-St-New-York-NY/40.747654,-73.986113_ll/',
#  '/homedetails/522-W-29th-St-10B-New-York-NY-10001/2106456199_zpid/',
#  '/homedetails/522-W-29th-St-9A-New-York-NY-10001/2096425505_zpid/',
#  '/b/777-6th-avenue-manhattan-ny-5XT2sc/',
#  '/b/15-Hudson-Yards-New-York-NY/40.7507,-73.9883_ll/',
#  '/homedetails/537-W-27th-St-APT-3I-New-York-NY-10001/2115074765_zpid/',
#  '/b/360-W-34th-St-New-York-NY/40.752783,-73.995237_ll/',
#  '/homedetails/411-W-35th-St-APT-7H-New-York-NY-10001/2085022036_zpid/',
#  '/b/50-W-34th-St-New-York-NY/40.748986,-73.986255_ll/',
#  '/homedetails/500-W-25th-St-4-New-York-NY-10001/2085022339_zpid/',
#  '/homedetails/35-Hudson-Yards-5805-New-York-NY-10001/2085022312_zpid/',
#  '/b/the-epic-new-york-ny-6QjG/',
#  '/homedetails/331-W-35th-St-APT-1R-New-York-NY-10001/2085024143_zpid/',
#  '/b/433-W-34th-St-New-York-NY/40.754294,-73.997743_ll/',
# ...

# %%
len(links)
# Out:
# 891

# %%
df = pd.DataFrame(links)

# %%
df.to_csv('links.csv')

# %%
req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

location = 'Midtown'

with requests.Session() as s:
    url = 'https://www.zillow.com/homes/'+location+'-New-York-NY_rb/' # 
    r = s.get(url, headers=req_headers)

# %%
# midtown neighbors
location =['Midtown','Columbus-Circle', 'Flatiron-District', 'Garment-District', 'Theater-District', 'Chelsea',
           'Turtle-Bay','Murray-Hill','Tudor-City', 'Gramercy',"Hell's-Kitchen","Flatiron-District"
           ,'Stuyvesant-Town']

# %%
location ='Midtown'

# %%
soup = BeautifulSoup(r.content, 'lxml')
price = soup.find('span', {'class': 'zsg-photo-card-price'}).text
info = soup.find('span', {'class': 'zsg-photo-card-info'}).text
address = soup.find('span', {'itemprop': 'address'}).text

# %%
links = list()
tags = soup.find_all('div', {'class': 'zsg-photo-card-content zsg-aspect-ratio-content'})
for tag in tags:
    links.append(tag.find('a').get('href'))
#link
#pagination
#random.sleep(10)
for i in range(2, 20):
    try:
        next_page_url = 'https://www.zillow.com/homes/'+zipcode+'_rb/'+str(i)+'_p/'
        r = s.get(next_page_url, headers=req_headers)
        soup = BeautifulSoup(r.content, 'lxml')
        tags = soup.find_all('div', {'class': 'zsg-photo-card-content zsg-aspect-ratio-content'})
        for tag in tags:
            links.append(tag.find('a').get('href'))
    except:
        # no next page
        break
    #sleep(random())
    
#return links

# %%
len(links)
# Out:
# 25

# %%
links
# Out:
# ['/b/150-W-51st-St-New-York-NY/40.761772,-73.983289_ll/',
#  '/b/240-Central-Park-S-New-York-NY/40.767311,-73.981176_ll/',
#  '/homedetails/55-W-55th-St-APT-8C-New-York-NY-10019/2121495967_zpid/',
#  '/b/205-W-54th-St-New-York-NY/40.763835,-73.98163_ll/',
#  '/homedetails/112-W-56th-St-APT-22S-New-York-NY-10019/31512723_zpid/',
#  '/b/888-8th-Ave-New-York-NY/40.763845,-73.984764_ll/',
#  '/b/152-W-49th-St-New-York-NY/40.760043,-73.983301_ll/',
#  '/b/721-5th-Ave-New-York-NY/40.762312,-73.97389_ll/',
#  '/b/25-columbus-circle-new-york-ny-5Xj5jj/',
#  '/b/20-W-53rd-St-New-York-NY/40.760546,-73.976495_ll/',
#  '/homedetails/200-W-54th-St-APT-10J-New-York-NY-10019/244895069_zpid/',
#  '/b/200-Central-Park-S-New-York-NY/40.766677,-73.979737_ll/',
#  '/b/the-ellington-new-york-ny-5YtQ6S/',
#  '/b/57-W-58th-St-New-York-NY/40.765049,-73.976251_ll/',
#  '/b/271-W-47th-St-New-York-NY/40.760206,-73.986628_ll/',
#  '/homedetails/52-W-55th-St-APT-3F-New-York-NY-10019/2085024625_zpid/',
# ...

# %%
len(set(links))
# Out:
# 473

# %%
l = [1,1,1,1]
set(l)
# Out:
# {1}

# %%
next_page
# Out:
# <li class="zsg-pagination-next"><a class="on" href="/homes/Midtown-New-York-NY_rb/2_p/" onclick="SearchMain.changePage(2);return false;">Next</a></li>

# %%
<ol class="zsg-pagination" id="yui_3_18_1_1_1554693123556_11425"><li class="zsg-pagination_active"><a>1</a></li><li id="yui_3_18_1_1_1554693123556_11424"><a href="/homes/for_sale/270885_rid/0_singlestory/40.831151,-73.893099,40.7416,-74.045019_rect/12_zm/2_p/" onclick="SearchMain.changePage(2);return false;" id="yui_3_18_1_1_1554693123556_11423">2</a></li><li id="yui_3_18_1_1_1554693123556_11429"><a href="/homes/for_sale/270885_rid/0_singlestory/40.831151,-73.893099,40.7416,-74.045019_rect/12_zm/3_p/" onclick="SearchMain.changePage(3);return false;" id="yui_3_18_1_1_1554693123556_11428">3</a></li><li><a href="/homes/for_sale/270885_rid/0_singlestory/40.831151,-73.893099,40.7416,-74.045019_rect/12_zm/4_p/" onclick="SearchMain.changePage(4);return false;">4</a></li><li><a href="/homes/for_sale/270885_rid/0_singlestory/40.831151,-73.893099,40.7416,-74.045019_rect/12_zm/5_p/" onclick="SearchMain.changePage(5);return false;">5</a></li><li class="zsg-pagination-ellipsis"><span>...</span></li><li><a href="/homes/for_sale/270885_rid/0_singlestory/40.831151,-73.893099,40.7416,-74.045019_rect/12_zm/16_p/" onclick="SearchMain.changePage(16);return false;">16</a></li><li class="zsg-pagination-next"><a href="/homes/for_sale/270885_rid/0_singlestory/40.831151,-73.893099,40.7416,-74.045019_rect/12_zm/2_p/" class="off" onclick="SearchMain.changePage(2);return false;">Next</a></li></ol>

# %%
<li class="zsg-pagination-next"><a href="/homes/for_sale/270885_rid/0_singlestory/40.831151,-73.893099,40.7416,-74.045019_rect/12_zm/2_p/" class="off" onclick="SearchMain.changePage(2);return false;">Next</a></li>
# Out:
# []

# %%
price = soup.find_all('span', {'class': 'zsg-photo-card-price'})

# %%
price
# Out:
# [<span class="zsg-photo-card-price">$1,346,200</span>,
#  <span class="zsg-photo-card-price">$1,595,000</span>,
#  <span class="zsg-photo-card-price">$3,300/mo</span>,
#  <span class="zsg-photo-card-price">$6,450,000</span>,
#  <span class="zsg-photo-card-price">$419,000</span>,
#  <span class="zsg-photo-card-price">$39,995,000</span>]

# %%
price
# Out:
# '$1,346,200'

# %%
<div class="zsg-photo-card-content zsg-aspect-ratio-content" itemscope="" itemtype="http://schema.org/SingleFamilyResidence" id="yui_3_18_1_1_1554693123556_6431"><span class="hide" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress"><span itemprop="streetAddress">53 W 53rd St # PH76</span><span itemprop="addressLocality"> New York </span><span itemprop="addressRegion">NY </span><span itemprop="postalCode" class="hide">10019</span></span><span itemprop="geo" itemscope="" itemtype="http://schema.org/GeoCoordinates"><meta itemprop="latitude" content="40.7616"><meta itemprop="longitude" content="-73.978401"></span><div class="zsg-photo-card-caption"><h4 class="zsg-photo-card-spec"><span class="zsg-photo-card-status"><span class="zsg-icon-for-sale"></span>Condo for sale</span></h4><p class="zsg-photo-card-spec"><span class="zsg-photo-card-price">$63,815,000</span><span class="zsg-photo-card-info">4 bds <span class="interpunct">·</span> 5 ba <span class="interpunct">·</span> 7,973 sqft</span></p><p class="zsg-photo-card-spec"><span class="zsg-photo-card-address">53 W 53rd St # PH76, New York, NY</span></p></div><a href="/homedetails/53-W-53rd-St-PH76-New-York-NY-10019/2087724598_zpid/" class="zsg-photo-card-overlay-link routable hdp-link routable mask hdp-link" id="yui_3_18_1_1_1554693123556_6430"></a><div class="zsg-photo-card-img"><ul class="zsg-list_inline zsg-photo-card-badge"><li class="">198 days on Zillow</li></ul><img src="https://photos.zillowstatic.com/p_e/IS2fordrt0njfa1000000000.jpg"></div><div class="zsg-photo-card-actions lh-hide "><a href="/myzillow/UpdateFavorites.htm?zpid=2087724598&amp;operation=add&amp;ajax=false" rel="nofollow" data-fm-zpid="2087724598" data-fm-callback="resultListSaveFavoriteSuccessHandler" data-auth-process="searchlistcard/save" data-save-home-reg-success-handler="resultListSaveFavoriteSuccessHandler" title="Save this home" data-show-home-owner-lightbox="false" data-za-label="Save Map:List" data-address="53 W 53rd St # PH76, New York, NY 10019" class="fm-save-event" id="auth_SaveFavoriteAuthCheck_0"><span class="image-control sprite-heart-line new-save-hide-icon larger-save"></span></a></div></div>
